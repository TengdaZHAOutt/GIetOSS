# %% [markdown]
# # Classification avec un neurone - Descente de gradient
#
# Nous souhaitons pouvoir dire pour chaque point d'un plan s’il devrait être colorié en rouge ou bien en bleu à partir d'informations issues d'un jeu de données initial. Pour cela on décide de construire le réseau le plus simple possible : avec un seul neurone. Cela correspond donc à séparer les points du plan selon une droite. La dimension de
# l’entrée est 2, les coordonnées (x, y) de chaque point du jeux initial, et celle la sortie est 1, point rouge ou bleu. Nous utiliserons la fonction d'activation sigmoide. Il y faut déterminer les paramètres, correspondant aux poids et au biais, qui permettent de trouver cette droite.

# %% [markdown]
# ## Apprentissage
# Pour trouver les paramètres du neurone qui définissent la meilleure fonction F permettant la classification des données, il s’agit de minimiser l’erreur E (comme vu en cours). Pour cela on utilise la méthode de la descente de gradient. Pour cela il vous faudra trouver puis implémenter les équations associées.
#
# Nous allons utiliser python et les packages de base ci-dessous.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Nous allons maintenant définir les différentes fonctions qui nous permettront de résoudre notre problème.
#
# ### Fonction d'activation
# Définir la fonction sigmoïde

# %%
def sigmoide(x):
    
    return 1/(1+np.exp(-x))

# %% [markdown]
# ### Fonction d'erreur
# Déterminer l’erreur locale pour la donnée numéro $i$ et l'erreur globale. Construire la fonction associée.

# %%
def E(w1, w2, b):
    somme_rouges=sum([(sigmoide(w1*x1+w2*x2+b)-1)**2 for x1,x2 in carres_rouges])
    somme_bleus=sum([(sigmoide(w1*x1+w2*x2+b)-0)**2 for x1,x2 in ronds_bleus])
    return

# %% [markdown]
# ### Calcul des gradients
# Déterminer les expressions des différents gradients et construire les fonctions associées.

# %%
def calcul_grad(w1, w2, b, y, data):
    gw1 = 1/N*sum([2*x1*sigmoide(w1*x1+w2*x2+b)*(1-sigmoide(w1*x1+w2*x2+b))*(sigmoide(w1*x1+w2*x2+b)-y) for x1,x2 in data])
    gw2 = 1/N*sum([2*x2*sigmoide(w1*x1+w2*x2+b)*(1-sigmoide(w1*x1+w2*x2+b))*(sigmoide(w1*x1+w2*x2+b)-y) for x1,x2 in data])
    gb =  1/N*sum([2*sigmoide(w1*x1+w2*x2+b)*(1-sigmoide(w1*x1+w2*x2+b))*(sigmoide(w1*x1+w2*x2+b)-y) for x1,x2 in data])

    return gw1, gw2, gb

# %%
def grad_E(w1, w2, b):
    gw1_red, gw2_red, gb_red = calcul_grad(w1, w2, b, 1, carres_rouges)
    gw1_blu, gw2_blu, gb_blu = calcul_grad(w1, w2, b, 0, ronds_bleus)
    
    return np.array([gw1_red+gw1_blu, gw2_red+gw2_blu, gb_red+gb_blu])

# %% [markdown]
# ### Algorithme de descente de gradient
# Construire l'algorithme de descente de gradient qui fera appel aux fonctions précédentes.

# %%
def descente(theta0, delta=0.1, nmax=10):
    liste_theta = [theta0] # sauvegarde valeurs successive de X
    liste_grad = [] # sauvegarde valeurs successives du gradient
    theta = theta0
    for i in range(nmax):
        gradient = grad_E(theta[0],theta[1],theta[2])
        theta = liste_theta[i]-delta*gradient
        liste_theta.append(theta)
        liste_grad.append(gradient)
   
    return liste_theta, liste_grad

# %% [markdown]
# ### Fonctions d'affichage des résultats

# %%
def affiche_descente(f, liste_theta, liste_grad, delta, nmax=10):
    print("vitesse d'apprentissage : ",delta)
    print("Nombre d'itérations :", nmax)
    print("Paramètres initiaux :", theta0)
    for i in range(len(liste_theta)-1):
        print("--- Etape",i)
        print("Paramètres :", *liste_theta[i])
        print("Gradient ", *liste_grad[i])
        print("Valeur de la fonction coût ", f(*liste_theta[i]))
    print("--- --------------------")
    print("Dernier point :", *liste_theta[-1])
    print("Dernière valeur de la fonction coût ", f(*liste_theta[-1]))
    print("--- --------------------")
    return

# %%
def graphique_points(w1, w2, b):
    for x, y in carres_rouges:    
        plt.scatter(x, y, marker='s', color='red')
    for x, y in ronds_bleus:   
        plt.scatter(x, y, color='blue')

    VX = np.linspace(-0.5, 5.5, 100)
    VY = -1/w2*(w1*VX+b)

    #  affichage
    plt.plot(VX, VY, color='black')
    plt.axis('equal')
    plt.xlim(-0.5,5.5)
    plt.ylim(-0.5,5.5)
    plt.tight_layout()
    plt.show()
    return

# %% [markdown]
# ### Mise en oeuvre
# Vous pouvez maintenant tester votre solution à partir de l'exemple ci-dessous

# %%
# Génération des données initiales : carré rouge / rond bleu 
carres_rouges = [(1,1), (2,0.5), (2,2), (3,1.5), (3,2.75), (4,1), (4,2.5), (4.5,3), (5,1), (5,2.25)]
ronds_bleus   = [(0,3), (1,1.5), (1,4), (1.5,2.5), (2,2.5), (3,3.5), (3.5,3.25), (4,3), (4,4), (5,4)] 

N = len(carres_rouges) + len(ronds_bleus)    # taille des données
 
# initialisation des paramètres du neurone
theta0 = np.array([0, 1, -2])

# recherche des paramètres du neurone
mon_delta = 1
mon_nmax = 100
liste_theta, liste_grad = descente(theta0, delta=mon_delta, nmax=mon_nmax)

affiche_descente(E, liste_theta, liste_grad, delta=mon_delta, nmax=mon_nmax)

w1, w2, b = liste_theta[-1]
print("Coefficients w1, w2, b du neurone et de la droite de séparation :", round(w1,5), round(w2,5), round(b,5))

graphique_points(w1, w2, b)
# Out:
# vittesse d'apprentissage :  1
# Nombre d'itérations : 100
# Paramètres initiaux : [ 0  1 -2]
# --- Etape 0
# Paramètres : 0 1 -2
# Gradient  -0.07742597934669859 0.1923976630907675 0.005898813617563323
# Valeur de la fonction coût  None
# --- Etape 1
# Paramètres : 0.07742597934669859 0.8076023369092324 -2.0058988136175633
# Gradient  -0.07229789519853097 0.21367880327269373 0.006912417227522699
# Valeur de la fonction coût  None
# --- Etape 2
# Paramètres : 0.14972387454522956 0.5939235336365387 -2.012811230845086
# Gradient  -0.09447201822571627 0.18899311196693225 -0.0062153938298749045
# Valeur de la fonction coût  None
# --- Etape 3
# Paramètres : 0.24419589277094583 0.40493042166960647 -2.006595837015211
# Gradient  -0.12051737190317818 0.13725086761458333 -0.02377902084193509
# Valeur de la fonction coût  None
# --- Etape 4
# Paramètres : 0.364713264674124 0.26767955405502314 -1.9828168161732758
# Gradient  -0.0905641894390743 0.12676776854549054 -0.024080204334560318
# Valeur de la fonction coût  None
# --- Etape 5
# Paramètres : 0.4552774541131983 0.1409117855095326 -1.9587366118387155
# Gradient  -0.07300210048056704 0.10914070698576023 -0.026376778616693866
# Valeur de la fonction coût  None
# --- Etape 6
# Paramètres : 0.5282795545937653 0.03177107852377237 -1.9323598332220215
# Gradient  -0.05996451693921284 0.0950597015422926 -0.027873746959549195
# Valeur de la fonction coût  None
# --- Etape 7
# Paramètres : 0.5882440715329782 -0.06328862301852023 -1.9044860862624724
# Gradient  -0.05151436880512583 0.08344892857875988 -0.02909469717738558
# Valeur de la fonction coût  None
# --- Etape 8
# Paramètres : 0.639758440338104 -0.1467375515972801 -1.8753913890850868
# Gradient  -0.04486183633343549 0.07466423842739384 -0.02977400437492994
# Valeur de la fonction coût  None
# --- Etape 9
# Paramètres : 0.6846202766715395 -0.22140179002467394 -1.845617384710157
# Gradient  -0.040081197113641664 0.06741137147879478 -0.030276104912804178
# Valeur de la fonction coût  None
# --- Etape 10
# Paramètres : 0.7247014737851811 -0.2888131615034687 -1.8153412797973527
# Gradient  -0.03605427713081821 0.06165689944019276 -0.030517260771033144
# Valeur de la fonction coût  None
# --- Etape 11
# Paramètres : 0.7607557509159993 -0.35047006094366145 -1.7848240190263196
# Gradient  -0.032900284772046706 0.05676656522762913 -0.03066731978692913
# Valeur de la fonction coût  None
# --- Etape 12
# Paramètres : 0.793656035688046 -0.4072366261712906 -1.7541566992393904
# Gradient  -0.030148166253651604 0.05270793894917761 -0.030690335451743364
# Valeur de la fonction coût  None
# --- Etape 13
# Paramètres : 0.8238042019416976 -0.4599445651204682 -1.723466363787647
# Gradient  -0.027856913373868447 0.049180071074649084 -0.030662184346650773
# Valeur de la fonction coût  None
# --- Etape 14
# Paramètres : 0.851661115315566 -0.5091246361951173 -1.6928041794409963
# Gradient  -0.02582160500439548 0.04614734888974953 -0.030570170297967658
# Valeur de la fonction coût  None
# --- Etape 15
# Paramètres : 0.8774827203199614 -0.5552719850848669 -1.6622340091430285
# Gradient  -0.02405547347300635 0.04346449152895637 -0.030447530778412696
# Valeur de la fonction coût  None
# --- Etape 16
# Paramètres : 0.9015381937929678 -0.5987364766138232 -1.6317864783646159
# Gradient  -0.022467734188163863 0.04109662815250131 -0.03029199040604094
# Valeur de la fonction coût  None
# --- Etape 17
# Paramètres : 0.9240059279811317 -0.6398331047663246 -1.6014944879585749
# Gradient  -0.021051941348570746 0.03897084295911532 -0.03011813623421534
# Valeur de la fonction coût  None
# --- Etape 18
# Paramètres : 0.9450578693297025 -0.67880394772544 -1.5713763517243595
# Gradient  -0.019766073830364106 0.0370579968725426 -0.029927302563356253
# Valeur de la fonction coût  None
# --- Etape 19
# Paramètres : 0.9648239431600666 -0.7158619445979826 -1.5414490491610033
# Gradient  -0.018598875155382943 0.03531895316685718 -0.029726180090210462
# Valeur de la fonction coût  None
# --- Etape 20
# Paramètres : 0.9834228183154495 -0.7511808977648398 -1.511722869070793
# Gradient  -0.01752906719999206 0.033731690006673865 -0.029516767498670778
# Valeur de la fonction coût  None
# --- Etape 21
# Paramètres : 1.0009518855154416 -0.7849125877715136 -1.4822061015721222
# Gradient  -0.016546313131141743 0.032273343295046886 -0.029302413829309003
# Valeur de la fonction coût  None
# --- Etape 22
# Paramètres : 1.0174981986465834 -0.8171859310665606 -1.4529036877428132
# Gradient  -0.01563845893161192 0.030928066296864398 -0.029084812211848707
# Valeur de la fonction coût  None
# --- Etape 23
# Paramètres : 1.0331366575781953 -0.848113997363425 -1.4238188755309644
# Gradient  -0.014797411676937905 0.02968137075507718 -0.028865812177750014
# Valeur de la fonction coût  None
# --- Etape 24
# Paramètres : 1.047934069255133 -0.8777953681185021 -1.3949530633532143
# Gradient  -0.014015397474966024 0.028522001543140163 -0.028646626909145656
# Valeur de la fonction coût  None
# --- Etape 25
# Paramètres : 1.061949466730099 -0.9063173696616422 -1.3663064364440687
# Gradient  -0.013286368098169576 0.02744016491376844 -0.028428349466712306
# Valeur de la fonction coût  None
# --- Etape 26
# Paramètres : 1.0752358348282687 -0.9337575345754107 -1.3378780869773563
# Gradient  -0.012604924065240275 0.02642779384154617 -0.028211780537800837
# Valeur de la fonction coût  None
# --- Etape 27
# Paramètres : 1.0878407588935088 -0.9601853284169568 -1.3096663064395555
# Gradient  -0.011966554205166902 0.025477943256226127 -0.027997577708454922
# Valeur de la fonction coût  None
# --- Etape 28
# Paramètres : 1.0998073130986756 -0.9856632716731829 -1.2816687287311006
# Gradient  -0.011367301524742662 0.024584711470221593 -0.0277862353116844
# Valeur de la fonction coût  None
# --- Etape 29
# Paramètres : 1.1111746146234183 -1.0102479831434046 -1.2538824934194162
# Gradient  -0.01080374858065225 0.023742990233249023 -0.027578134366967884
# Valeur de la fonction coût  None
# --- Etape 30
# Paramètres : 1.1219783632040705 -1.0339909733766537 -1.2263043590524483
# Gradient  -0.01027289000384185 0.02294835414005983 -0.02737355228340802
# Valeur de la fonction coût  None
# --- Etape 31
# Paramètres : 1.1322512532079123 -1.0569393275167136 -1.1989308067690403
# Gradient  -0.009772083406887011 0.02219693220835872 -0.027172684967915556
# Valeur de la fonction coût  None
# --- Etape 32
# Paramètres : 1.1420233366147994 -1.0791362597250722 -1.1717581218011248
# Gradient  -0.009298985980089464 0.02148532266952244 -0.026975658794537033
# Valeur de la fonction coût  None
# --- Etape 33
# Paramètres : 1.1513223225948888 -1.1006215823945946 -1.1447824630065877
# Gradient  -0.008851513344601908 0.020810516189328915 -0.02678254336590325
# Valeur de la fonction coût  None
# --- Etape 34
# Paramètres : 1.1601738359394906 -1.1214320985839235 -1.1179999196406845
# Gradient  -0.008427801304359495 0.02016983685188689 -0.0265933610098398
# Valeur de la fonction coût  None
# --- Etape 35
# Paramètres : 1.1686016372438501 -1.1416019354358102 -1.0914065586308446
# Gradient  -0.008026176170196575 0.019560892454938944 -0.026408095278883874
# Valeur de la fonction coût  None
# --- Etape 36
# Paramètres : 1.1766278134140467 -1.161162827890749 -1.0649984633519607
# Gradient  -0.007645129286905472 0.018981534232908603 -0.02622669791664875
# Valeur de la fonction coût  None
# --- Etape 37
# Paramètres : 1.1842729427009522 -1.1801443621236576 -1.038771765435312
# Gradient  -0.00728329603456479 0.018429823299567466 -0.026049094839292936
# Valeur de la fonction coût  None
# --- Etape 38
# Paramètres : 1.191556238735517 -1.198574185423225 -1.012722670596019
# Gradient  -0.00693943800700475 0.01790400283697416 -0.02587519117162112
# Valeur de la fonction coût  None
# --- Etape 39
# Paramètres : 1.1984956767425217 -1.2164781882601992 -0.986847479424398
# Gradient  -0.006612427957138678 0.017402474797043682 -0.025704875533682878
# Valeur de la fonction coût  None
# --- Etape 40
# Paramètres : 1.2051081046996603 -1.2338806630572428 -0.9611426038907152
# Gradient  -0.006301236941008925 0.016923780323862825 -0.025538023674119142
# Valeur de la fonction coût  None
# --- Etape 41
# Paramètres : 1.2114093416406693 -1.2508044433811056 -0.935604580216596
# Gradient  -0.006004923302900783 0.01646658319410854 -0.02537450155582234
# Valeur de la fonction coût  None
# --- Etape 42
# Paramètres : 1.21741426494357 -1.267271026575214 -0.9102300786607737
# Gradient  -0.005722623178121944 0.016029655742014898 -0.02521416797240992
# Valeur de la fonction coût  None
# --- Etape 43
# Paramètres : 1.223136888121692 -1.283300682317229 -0.8850159106883637
# Gradient  -0.0054535422665790145 0.015611866830128635 -0.02505687676530939
# Valeur de la fonction coût  None
# --- Etape 44
# Paramètres : 1.2285904303882709 -1.2989125491473577 -0.8599590339230543
# Gradient  -0.00519694867177517 0.01521217151624682 -0.024902478699072028
# Valeur de la fonction coût  None
# --- Etape 45
# Paramètres : 1.233787379060046 -1.3141247206636044 -0.8350565552239823
# Gradient  -0.004952166639680983 0.014829602132192005 -0.0247508230443145
# Valeur de la fonction coût  None
# --- Etape 46
# Paramètres : 1.238739545699727 -1.3289543227957965 -0.8103057321796677
# Gradient  -0.004718571061075039 0.01446326054391986 -0.024601758910142157
# Valeur de la fonction coût  None
# --- Etape 47
# Paramètres : 1.243458116760802 -1.3434175833397164 -0.7857039732695256
# Gradient  -0.004495582625173911 0.014112311404714584 -0.02445513636181413
# Valeur de la fonction coût  None
# --- Etape 48
# Paramètres : 1.2479536993859761 -1.357529894744431 -0.7612488369077114
# Gradient  -0.004282663531539055 0.013775976247306976 -0.02431080735418377
# Valeur de la fonction coût  None
# --- Etape 49
# Paramètres : 1.252236362917515 -1.3713058709917378 -0.7369380295535276
# Gradient  -0.0040793136828268795 0.013453528288070199 -0.024168626507044252
# Valeur de la fonction coût  None
# --- Etape 50
# Paramètres : 1.2563156766003418 -1.384759399279808 -0.7127694030464834
# Gradient  -0.0038850672935745734 0.013144287838500884 -0.024028451744756547
# Valeur de la fonction coût  None
# --- Etape 51
# Paramètres : 1.2602007438939165 -1.3979036871183088 -0.6887409513017269
# Gradient  -0.0036994898605243742 0.012847618237037256 -0.023890144819343734
# Valeur de la fonction coût  None
# --- Etape 52
# Paramètres : 1.2639002337544407 -1.410751305355346 -0.6648508064823831
# Gradient  -0.0035221754484308088 0.012562922228770479 -0.02375357173350348
# Valeur de la fonction coût  None
# --- Etape 53
# Paramètres : 1.2674224092028714 -1.4233142275841164 -0.6410972347488797
# Gradient  -0.0033527442522554574 0.012289638732426278 -0.023618603077656994
# Valeur de la fonction coût  None
# --- Etape 54
# Paramètres : 1.2707751534551268 -1.4356038663165427 -0.6174786316712227
# Gradient  -0.0031908404024173775 0.012027239943657758 -0.023485114293157888
# Valeur de la fonction coût  None
# --- Etape 55
# Paramètres : 1.2739659938575443 -1.4476311062602005 -0.5939935173780648
# Gradient  -0.0030361299845387824 0.01177522873164949 -0.023352985872068188
# Valeur de la fonction coût  None
# --- Etape 56
# Paramètres : 1.277002123842083 -1.45940633499185 -0.5706405315059966
# Gradient  -0.0028882992491371384 0.011533136292564389 -0.023222103502447362
# Valeur de la fonction coût  None
# --- Etape 57
# Paramètres : 1.2798904230912203 -1.4709394712844144 -0.5474184280035492
# Gradient  -0.0027470529900481266 0.01130052002879725 -0.023092358166838647
# Valeur de la fonction coût  None
# --- Etape 58
# Paramètres : 1.2826374760812684 -1.4822399913132116 -0.5243260698367106
# Gradient  -0.002612113073201555 0.011076961627484172 -0.02296364620056504
# Valeur de la fonction coût  None
# --- Etape 59
# Paramètres : 1.28524958915447 -1.4933169529406958 -0.5013624236361456
# Gradient  -0.002483217099739643 0.010862065315481062 -0.022835869315519113
# Valeur de la fonction coût  None
# --- Etape 60
# Paramètres : 1.2877328062542097 -1.5041790182561767 -0.47852655432062646
# Gradient  -0.002360117189510069 0.010655456271151609 -0.02270893459434494
# Valeur de la fonction coût  None
# --- Etape 61
# Paramètres : 1.2900929234437197 -1.5148344745273283 -0.45581761972628154
# Gradient  -0.00224257887267737 0.010456779175948838 -0.02258275445923045
# Valeur de la fonction coût  None
# --- Etape 62
# Paramètres : 1.2923355023163972 -1.5252912537032772 -0.4332348652670511
# Gradient  -0.0021303800786752203 0.010265696891001375 -0.02245724661894903
# Valeur de la fonction coût  None
# --- Etape 63
# Paramètres : 1.2944658823950723 -1.5355569505942785 -0.410777618648102
# Gradient  -0.002023310213003726 0.010081889245782127 -0.02233233399729749
# Valeur de la fonction coût  None
# --- Etape 64
# Paramètres : 1.296489192608076 -1.5456388398400607 -0.3884452846508045
# Gradient  -0.0019211693134387198 0.009905051927563746 -0.022207944645647
# Valeur de la fonction coût  None
# --- Etape 65
# Paramètres : 1.2984103619215146 -1.5555438917676243 -0.3662373400051575
# Gradient  -0.0018237672781980796 0.009734895461702753 -0.022084011641968417
# Valeur de la fonction coût  None
# --- Etape 66
# Paramètres : 1.3002341291997126 -1.565278787229327 -0.34415332836318907
# Gradient  -0.0017309231593991559 0.009571144273986587 -0.021960472978378706
# Valeur de la fonction coût  None
# --- Etape 67
# Paramètres : 1.3019650523591118 -1.5748499315033135 -0.32219285538481035
# Gradient  -0.001642464515873715 0.009413535827269615 -0.02183727143899436
# Valeur de la fonction coût  None
# --- Etape 68
# Paramètres : 1.3036075168749854 -1.584263467330583 -0.30035558394581596
# Gradient  -0.0015582268200164118 0.00926181982550009 -0.02171435446964974
# Valeur de la fonction coût  None
# --- Etape 69
# Paramètres : 1.305165743695002 -1.5935252871560832 -0.2786412294761662
# Gradient  -0.0014780529138944676 0.009115757478988767 -0.02159167404084783
# Valeur de la fonction coût  None
# --- Etape 70
# Paramètres : 1.3066437966088964 -1.602641044635072 -0.2570495554353184
# Gradient  -0.0014017925103190776 0.00897512082542587 -0.021469186505144358
# Valeur de la fonction coût  None
# --- Etape 71
# Paramètres : 1.3080455891192155 -1.611616165460498 -0.23558036893017403
# Gradient  -0.0013293017349997882 0.00883969210172611 -0.021346852450026536
# Valeur de la fonction coût  None
# --- Etape 72
# Paramètres : 1.3093748908542153 -1.620455857562224 -0.2142335164801475
# Gradient  -0.0012604427062815338 0.00870926316227566 -0.02122463654722817
# Valeur de la fonction coût  None
# --- Etape 73
# Paramètres : 1.3106353335604968 -1.6291651207244997 -0.19300887993291932
# Gradient  -0.0011950831492760772 0.008583634939607732 -0.021102507399316336
# Valeur de la fonction coût  None
# --- Etape 74
# Paramètres : 1.311830416709773 -1.6377487556641075 -0.17190637253360297
# Gradient  -0.0011330960415169289 0.008462616943902629 -0.020980437384301366
# Valeur de la fonction coût  None
# --- Etape 75
# Paramètres : 1.31296351275129 -1.64621137260801 -0.1509259351493016
# Gradient  -0.001074359287496135 0.008346026798074002 -0.02085840249893884
# Valeur de la fonction coût  None
# --- Etape 76
# Paramètres : 1.3140378720387862 -1.654557399406084 -0.13006753265036278
# Gradient  -0.0010187554197008397 0.008233689805487845 -0.020736382201331692
# Valeur de la fonction coût  None
# --- Etape 77
# Paramètres : 1.315056627458487 -1.6627910892115718 -0.10933115044903108
# Gradient  -0.0009661713239550174 0.008125438547647537 -0.020614359253378692
# Valeur de la fonction coût  None
# --- Etape 78
# Paramètres : 1.316022798782442 -1.6709165277592193 -0.08871679119565239
# Gradient  -0.0009164979870707746 0.008021112509409817 -0.020492319563567153
# Valeur de la fonction coût  None
# --- Etape 79
# Paramètres : 1.3169392967695128 -1.6789376402686291 -0.06822447163208523
# Gradient  -0.0008696302649712773 0.007920557729522798 -0.020370252030561205
# Valeur de la fonction coût  None
# --- Etape 80
# Paramètres : 1.3178089270344842 -1.6868581979981518 -0.04785421960152402
# Gradient  -0.0008254666696057011 0.007823626474466702 -0.020248148387998426
# Valeur de la fonction coût  None
# --- Etape 81
# Paramètres : 1.3186343937040899 -1.6946818244726185 -0.027606071213525596
# Gradient  -0.0007839091731113856 0.007730176933753191 -0.0201260030508714
# Valeur de la fonction coût  None
# --- Etape 82
# Paramètres : 1.3194183028772013 -1.7024120014063717 -0.007480068162654195
# Gradient  -0.0007448630277960833 0.007640072935004655 -0.020003812963836964
# Valeur de la fonction coût  None
# --- Etape 83
# Paramètres : 1.3201631659049973 -1.7100520743413763 0.01252374480118277
# Gradient  -0.0007082366006385676 0.0075531836772674416 -0.01988157745176878
# Valeur de la fonction coût  None
# --- Etape 84
# Paramètres : 1.3208714025056358 -1.7176052580186438 0.03240532225295155
# Gradient  -0.0006739412210944318 0.007469383481152683 -0.01975929807283834
# Valeur de la fonction coût  None
# --- Etape 85
# Paramètres : 1.3215453437267302 -1.7250746414997966 0.05216462032578989
# Gradient  -0.0006418910410966316 0.007388551554511846 -0.019636978474385926
# Valeur de la fonction coût  None
# --- Etape 86
# Paramètres : 1.3221872347678267 -1.7324631930543084 0.07180159880017581
# Gradient  -0.0006120029062265664 0.007310571772458474 -0.019514624251818297
# Valeur de la fonction coût  None
# --- Etape 87
# Paramètres : 1.3227992376740534 -1.7397737648267668 0.0913162230519941
# Gradient  -0.0005841962371029297 0.0072353324706528055 -0.01939224281074669
# Valeur de la fonction coût  None
# --- Etape 88
# Paramètres : 1.3233834339111563 -1.7470090972974197 0.1107084658627408
# Gradient  -0.000558392920115669 0.007162726250848767 -0.01926984323255701
# Valeur de la fonction coût  None
# --- Etape 89
# Paramètres : 1.323941826831272 -1.7541718235482684 0.1299783090952978
# Gradient  -0.0005345172066969495 0.007092649797785372 -0.0191474361435841
# Valeur de la fonction coût  None
# --- Etape 90
# Paramètres : 1.324476344037969 -1.7612644733460538 0.14912574523888192
# Gradient  -0.0005124956203817199 0.007025003706581101 -0.01902503358804076
# Valeur de la fonction coût  None
# --- Etape 91
# Paramètres : 1.3249888396583507 -1.768289477052635 0.16815077882692267
# Gradient  -0.0004922568709692932 0.00695969231985584 -0.01890264890483368
# Valeur de la fonction coût  None
# --- Etape 92
# Paramètres : 1.32548109652932 -1.7752491693724908 0.18705342773175634
# Gradient  -0.00047373177514739573 0.006896623573869692 -0.018780296608379328
# Valeur de la fonction coût  None
# --- Etape 93
# Paramètres : 1.3259548283044673 -1.7821457929463604 0.20583372434013567
# Gradient  -0.000456853182995709 0.006835708853020761 -0.018657992273515972
# Valeur de la fonction coût  None
# --- Etape 94
# Paramètres : 1.3264116814874631 -1.7889815017993813 0.22449171661365164
# Gradient  -0.0004415559098245869 0.006776862852102675 -0.018535752424588894
# Valeur de la fonction coût  None
# --- Etape 95
# Paramètres : 1.3268532373972877 -1.795758364651484 0.24302746903824052
# Gradient  -0.00042777667285201493 0.006720003445764608 -0.0184135944287711
# Valeur de la fonction coût  None
# --- Etape 96
# Paramètres : 1.3272810140701397 -1.8024783680972487 0.2614410634670116
# Gradient  -0.00041545403225845545 0.006665051564667707 -0.01829153639366425
# Valeur de la fonction coût  None
# --- Etape 97
# Paramètres : 1.3276964681023982 -1.8091434196619165 0.2797325998606759
# Gradient  -0.000404528336200749 0.006611931077863453 -0.018169597069210695
# Valeur de la fonction coût  None
# --- Etape 98
# Paramètres : 1.3281009964385988 -1.81575535073978 0.29790219692988656
# Gradient  -0.0003949416693940777 0.00656056868096791 -0.018047795753930777
# Valeur de la fonction coût  None
# --- Etape 99
# Paramètres : 1.3284959381079928 -1.8223159194207479 0.31594999268381735
# Gradient  -0.00038663780490902355 0.00651089378973066 -0.017926152205487406
# Valeur de la fonction coût  None
# --- --------------------
# Dernier point : 1.328882575912902 -1.8288268132104786 0.3338761448893047
# Dernière valeur de la fonction coût  None
# --- --------------------
# Coefficients w1, w2, b du neurone et de la droite de séparation : 1.32888 -1.82883 0.33388

# %% [markdown]
# ### Commenter les résultats

# %% [markdown]
# ## Prédiction
# Vous avez obtenu par la descente de gradient les paramètres du neurone qui permettent de séparer le plan en deux parties. Il est maintenat possible de l'utiliser pour prédire à quelle classe appartient n'importe quel point de l'espace.
#
# Prédire par exemple, la classe des points de coordonnées (x1=2, x2=3) et de (x1=2, x2=1).

# %%
def graphique_new_points(x_new, y_new, new_label, w1, w2, b):
    for x, y in carres_rouges:    # points
        plt.scatter(x, y, marker='s', color='red')
    for x, y in ronds_bleus:    # points
        plt.scatter(x, y, color='blue')

    VX = np.linspace(-0.5, 5.5, 100)
    VY = -1/w2*(w1*VX+b)

    #  affichage données initiales et courbe
    plt.plot(VX, VY, color='black')
    plt.axis('equal')
    plt.xlim(-0.5,5.5)
    plt.ylim(-0.5,5.5)
    plt.tight_layout()
    
    if new_label==0:
        plt.scatter(x_new, y_new, marker='X', color='blue')
    else:
        plt.scatter(x_new, y_new, marker='X', color='red')    
    
    
    # plt.savefig('retro_01_e.png')
    plt.show()
    return

# %%
def predict(w1,w2,b,x1,x2):
    F=sigmoide(w1*x1+w2*x2+b)
    if F > 0.5:
        print('rouge', F)
        graphique_new_points(x1,x2, 1, w1, w2, b)
    else:
        print('bleu', F)
        graphique_new_points(x1,x2, 0, w1, w2, b)
    return

# %% [markdown]
# ### Commenter les résultats

# %%
predict(w1,w2,b,2,3)
predict(w1,w2,b,2,1)
# Out:
# bleu 0.08671538510619264
# rouge 0.6023107414149121
